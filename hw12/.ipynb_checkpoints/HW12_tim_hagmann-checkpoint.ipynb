# %% [markdown]
# **Homework 12**
#
# All the problems from homework 12 are beeing solved on an AWS c4.8xlarge instance. That means, that 36 Intel Xeon E5-2666 cores with a clock speed of 2.9 GHz are beeing used in parallel.

# %%
from IPython.display import Image
fig = Image(filename=('/home/tim/e63-coursework/hw12/img/p0_htop.png'))
fig

# %% [markdown]
# ## Problem 1 (45%)
# Please find attached 2 files from Google’s tutorials sets. I used file *mnist2.py* for preparation of my notes. If you read the file carefully you will see that you can run it in at least two modes. The way it is setup now it selects one learning rate and one particular neural network architecture and generates TensorBoard graph in a particular directory. One problem with this script is that its accuracy is surprisingly low. Such complex architecture and so many lines of code and we get 70% or lower accuracy. We expected more from Convolutional Neural Networks. File *cnn_mnist.py* is practically the same, at least it does all the same things, creates similar architecture, sets the same or similar parameters, but does a much better job. Its accuracy is in high 90%-s.
#
# **Question:** Run two files, compare results and then fix the first file *(mnist.py)* based on what you saw in file *cnn_mnist.py*.

# %% [markdown]
# ### mnist2.py
# The first step is to run the *mnist2.py* file.

# %%
# %run /home/tim/e63-coursework/hw12/mnist2.py
# Out:
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting log3/data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting log3/data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting log3/data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting log3/data/t10k-labels-idx1-ubyte.gz
# Starting run for lr_1E-04conv2fc2

# %% [markdown]
# Next I'm running tensorgraph to visualize the results.
# ```bash
# tensorboard --logdir=log3/lr_1E-04conv2fc2
# ```

# %%
fig = Image(filename=('/home/tim/e63-coursework/hw12/img/p1_1.png'))
fig

# %% [markdown]
# The above plot shows, that accuracy rate is at 85%.

# %% [markdown]
# ### cnn_mnist.py
# We can also run the *cnn_mnist.py* model

# %%
# %run /home/tim/e63-coursework/hw12/cnn_mnist.py
# Out:
# Extracting temp/train-images-idx3-ubyte.gz
# Extracting temp/train-labels-idx1-ubyte.gz
# Extracting temp/t10k-images-idx3-ubyte.gz
# Extracting temp/t10k-labels-idx1-ubyte.gz
# Generation # 5. Train Loss: 2.29. Train Acc (Test Acc): 17.00 (13.00)
# Generation # 10. Train Loss: 2.24. Train Acc (Test Acc): 18.00 (19.80)
# Generation # 15. Train Loss: 2.16. Train Acc (Test Acc): 24.00 (25.80)
# Generation # 20. Train Loss: 2.06. Train Acc (Test Acc): 35.00 (39.00)
# Generation # 25. Train Loss: 1.89. Train Acc (Test Acc): 50.00 (43.00)
# Generation # 30. Train Loss: 1.66. Train Acc (Test Acc): 65.00 (55.60)
# Generation # 35. Train Loss: 1.44. Train Acc (Test Acc): 68.00 (69.40)
# Generation # 40. Train Loss: 1.12. Train Acc (Test Acc): 74.00 (68.40)
# Generation # 45. Train Loss: 0.88. Train Acc (Test Acc): 77.00 (74.80)
# Generation # 50. Train Loss: 0.80. Train Acc (Test Acc): 76.00 (82.00)
# Generation # 55. Train Loss: 0.52. Train Acc (Test Acc): 90.00 (84.40)
# ...

# %% [markdown]
# The above output shows, that the accuracy rate on test data lies at 95%. As described in the problem statment, this value is better than the result from the *mnist2.py* model.

# %% [markdown]
# When comparing the two codes we can see, that the the *dropout* in order to avoid overfitting is missing in the *mnist2.py* script. That means the *mnist2.py* is overfitting the data and the accuracy can't get into the same hights as the *cnn_mnist.py* script. I did fix this in the *p1_mnist2.py* file.

# %% [markdown]
# **Question:** Capture the Accuracy and Cross Entropy (summary) graphs from the corrected version of *mnist2.py* and provide working and fixed version of that file.

# %%
# %run /home/tim/e63-coursework/hw12/p1_mnist2.py
# Out:
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting log3_fixeddata/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting log3_fixeddata/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting log3_fixeddata/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting log3_fixeddata/t10k-labels-idx1-ubyte.gz
# Starting run for lr_1E-04conv2fc2

# %% [markdown]
# Next I'm running tensorgraph to visualize the results.
# ```bash
# tensorboard --logdir=log3_fixedlr_1E-04conv2fc2
# ```

# %%
fig = Image(filename=('/home/tim/e63-coursework/hw12/img/p1_3.png'))
fig

# %% [markdown]
# With the fixed script the accuracy rate heavily increases and the cross entropy rate decreases. Avoiding overfitting leads to an accuracy rate of 97%. The model graph looks as follows:

# %%
fig = Image(filename=('/home/tim/e63-coursework/hw12/img/p1_4.png'))
fig

# %% [markdown]
# ## Problem 2 (20%)
# **Question:** Run a corrected version of *mnist2.py* for 4 different architectures (2 conv, 1 conv, 2 fully connected, 1 fully connected layer) and 3 values of the learning rate. As one learning rate choose the one you selected in Problem 1 and then add one smaller and one larger learning rate around that one.

# %% [markdown]
# First we're starting adapting the *mnist2.py* script. What is done is to change the *main()* function at the end of the script. The number of convolutional layers and the number of FC layers is beeing played with as well as three different learning rates: 1E-03 (1'000), 1E-04 (10'000), 1E-05 (100'000) are being set. The results of this are aved in the *p2_mnist2.py* script.
#
# With that we can run the *p2_mnist2.py* script:

# %%
# %run /home/tim/e63-coursework/hw12/p2_mnist2.py
# Out:
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting log3/data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting log3/data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting log3/data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting log3/data/t10k-labels-idx1-ubyte.gz
# Starting run for lr_1E-03conv2fc2
# Starting run for lr_1E-03conv1fc2
# Starting run for lr_1E-03conv2fc1
# Starting run for lr_1E-03conv1fc1
# Starting run for lr_1E-04conv2fc2
# Starting run for lr_1E-04conv1fc2
# Starting run for lr_1E-04conv2fc1
# Starting run for lr_1E-04conv1fc1
# Starting run for lr_1E-05conv2fc2
# Starting run for lr_1E-05conv1fc2
# Starting run for lr_1E-05conv2fc1
# Starting run for lr_1E-05conv1fc1

# %% [markdown]
# **Question:** Please capture an image of “colorful” T-SNE Embedding.

# %% [markdown]
# In order to have a look at the T-SNE Embedding, we're running the following command:
#
# ```bash
# tensorboard --logdir=log3/lr_1E-03conv2fc2
# ```
#
# We could look at any of the other log folders above.

# %%
from IPython.display import Image
fig = Image(filename=('/home/tim/e63-coursework/hw12/img/p2_img1.png'))
fig

# %%
fig = Image(filename=('/home/tim/e63-coursework/hw12/img/p2_img2.png'))
fig

# %% [markdown]
# **Question:** Capture Accuracy (summary) graphs and One of Histograms to demonstrate to us that your code is working.
#
# As above, I'm demonstrate that the code is working with conv2fc2. We're starting with the smallest learning rate and move on to the bigger ones.

# %% [markdown]
# #### Learning rate: 1E-03 (1'000)

# %%
fig = Image(filename=('/home/tim/e63-coursework/hw12/img/p2_conv2fc2_1e03_1.png'))
fig

# %%
fig = Image(filename=('/home/tim/e63-coursework/hw12/img/p2_conv2fc2_1e03_2.png'))
fig

# %% [markdown]
# #### Learning rate: 1E-04 (10'000)

# %%
fig = Image(filename=('/home/tim/e63-coursework/hw12/img/p2_conv2fc2_1e04_1.png'))
fig

# %%
fig = Image(filename=('/home/tim/e63-coursework/hw12/img/p2_conv2fc2_1e04_2.png'))
fig

# %% [markdown]
# #### Learning rate: 1E-05 (100'000)

# %%
fig = Image(filename=('/home/tim/e63-coursework/hw12/img/p2_conv2fc2_1e05_1.png'))
fig

# %%
fig = Image(filename=('/home/tim/e63-coursework/hw12/img/p2_conv2fc2_1e05_2.png'))
fig

# %% [markdown]
# **Question:** Collect execution times, final (smoothed) accuracies and final cross entropies for different models and provide tabulated presentation of the final results of different models.

# %% [markdown]
# | Architecture | Learning Rate | Execution Time | Smoothed Accuracy | Cross Entropy |
# | ------------ | -------------:| -------------- | ----------------- | ------------- |
# |2 Conv / 2 FC | 1E-03		   | 3m 15s	    	| 1.00		        | 0.006         |
# |              | 1E-04		   | 3m 15s			| 0.99		        | 0.025         |
# |              | 1E-05		   | 3m 14s		    | 0.1		        | 2.146         |
# |1 Conv / 1 FC | 1E-03		   | 2m 38s	    	| 0.29		        | 1.641         |
# |              | 1E-04		   | 2m 40s	     	| 0.39		        | 1.787         |
# |              | 1E-05		   | 2m 41s		    | 0.78		        | 0.842         |
# |2 Conv / 1 FC | 1E-03		   | 3m 54s 		| 0.07		        | 2.303         |
# |              | 1E-04		   | 3m 49s 		| 1.00		        | 0.035         |
# |              | 1E-05		   | 3m 47s		    | 0.92		        | 0.367         |
# |1 Conv / 2 FC | 1E-03		   | 2m 38s		    | 0.29		        | 2.400         |
# |              | 1E-04		   | 2m 40s		    | 0.37		        | 1.787         |
# |              | 1E-05		   | 2m 41s		    | 0.78		        | 0.842         |

# %% [markdown]
# The above table shows, that the 2 Conv / 2 FC model with a 1E-03 learning rate as well as the 2 Conv / 1 FC model with a 1E-04 learning rate perform the best with a smoothed accuracy of 1.00. Looking additionally at the corss entropy the 2 Conv 2 FC model with a 1E-03 learning rate performs the best.

# %% [markdown]
# ## Problem 3 (35%)
# **Question:** Modify file *cnn_mnist.py*  so that it publishes its summaries to the TensorBoard. Describe changes you are making.

# %% [markdown]
# I adapted in the the above file the accuracy calculations. This is beeing done on line 119 (see code addition below)
#
# ```python
# cor_prediction = tf.equal(tf.argmax(model_output, 1), tf.cast(y_target, tf.int64))
# accuracy = tf.reduce_mean(tf.cast(cor_prediction, tf.float32))
# tf.summary.scalar("accuracy", accuracy)```
#
# Furthermore, the loss function is beeing declared on line 103:
#
# ```python
# tf.summary.scalar('loss', loss)
# ```
#
# Following that the summaries can be merged and the writer is set to the *question3* directory on line 133 and 136.
#
# ```python
# writer = tf.summary.FileWriter('./question3', sess.graph)
#
# # Merge summaries
# merged = tf.summary.merge_all()
# ```
#
# Finally, the summary session is added to the writer on the lines 151 onwards:
#
# ```python
# _, s = sess.run([train_step, merged], feed_dict=train_dict)
# writer.add_summary(s, i)
# temp_train_loss,temp_train_acc, temp_train_preds = sess.run([loss, accuracy, prediction], feed_dict=train_dict)
# ```
#
# The overall working script can be found in the *p3_cnn_mnist.py* file. Having adapted the script we can run in with the following line:

# %%
# %run /home/tim/e63-coursework/hw12/p3_cnn_mnist.py
# Out:
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting temp/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting temp/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting temp/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting temp/t10k-labels-idx1-ubyte.gz
# Generation # 5. Train Loss: 2.24. Train Acc (Test Acc): 0.19 (13.40)
# Generation # 10. Train Loss: 2.18. Train Acc (Test Acc): 0.23 (20.40)
# Generation # 15. Train Loss: 2.03. Train Acc (Test Acc): 0.28 (30.20)
# Generation # 20. Train Loss: 2.01. Train Acc (Test Acc): 0.40 (45.40)
# Generation # 25. Train Loss: 1.80. Train Acc (Test Acc): 0.56 (59.00)
# Generation # 30. Train Loss: 1.44. Train Acc (Test Acc): 0.76 (68.60)
# Generation # 35. Train Loss: 1.20. Train Acc (Test Acc): 0.70 (74.40)
# ...

# %% [markdown]
# **Question:** Provide images of Accuracy and loss summaries as captured by the Tensor Board.
#
# We can visualize the tensorgraph images with the following command:
#
# ```bash
# tensorboard --logdir=question3
# ```

# %%
fig = Image(filename=('/home/tim/e63-coursework/hw12/img/p3_1.png'))
fig

# %% [markdown]
# **Question:** Provide the Graph of your model. Describe the differences if any between the graph of this program and the graph generated by *mnist2.py* script running with 2 convolutional and 2 fully connected layers.

# %%
fig = Image(filename=('/home/tim/e63-coursework/hw12/img/p3_2.png'))
fig

# %% [markdown]
# The above graph is different to the ones from the models used before. The major difference is, that *cnn_mnist.py* hase a separate model for training and testing and that the train model interacts with cross entropy (xent and the loss function), while the tested model does not. Furthermore, while the *mnist2.py* script is using using training accuracy the *cnn_mnist.py* uses test accuracy.
